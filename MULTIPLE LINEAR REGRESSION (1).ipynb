# %% [markdown]
# In \[1\]:
#
#     # importing the required libraries
#
#     import numpy as np
#     import pandas as pd
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     %matplotlib inline
#
# In \[3\]:
#
#     # here we have created the variable called dataset
#     # by using the pandas library we read the csv file
#
#     dataset = pd.read_csv('Ecommerce Customers (1).csv')
#
# In \[4\]:
#
#     # checking the 1 st 5 rows of the dataset
#
#     dataset.head()
#
#     # the observations are ;
#
#     # # we have the intrinsic indexes that appears automatically
#     # this includes email that means by which email the person has registererd into the
#     # ecoomerce website. email address are the identifiers .
#     # this includes the address
#     # # avatar ; we can choose it as per choice
#     # Avg. Session Length ; this means how much time we spent in one session
#     # Time on App ;  this tells how much time you spend by accessing the application
#     # Time on Website ;  this tells how much time you accessed the website for the particular application
#     # Length of Membership ;  this tells what is the total duration of the subscription of that
#     # application on the website done by the person
#     # Yearly Amount Spent ; this tells how much you amunt you  spent purchasing  the subscription
#
# Out\[4\]:
#
# |     | Email                         | Address                                            | Avatar           | Avg. Session Length | Time on App | Time on Website | Length of Membership | Yearly Amount Spent |
# |-----|-------------------------------|----------------------------------------------------|------------------|---------------------|-------------|-----------------|----------------------|---------------------|
# | 0   | mstephenson@fernandez.com     | 835 Frank Tunnel\\nWrightmouth, MI 82180-9605      | Violet           | 34.497268           | 12.655651   | 39.577668       | 4.082621             | 587.951054          |
# | 1   | hduke@hotmail.com             | 4547 Archer Common\\nDiazchester, CA 06566-8576    | DarkGreen        | 31.926272           | 11.109461   | 37.268959       | 2.664034             | 392.204933          |
# | 2   | pallen@yahoo.com              | 24645 Valerie Unions Suite 582\\nCobbborough, D... | Bisque           | 33.000915           | 11.330278   | 37.110597       | 4.104543             | 487.547505          |
# | 3   | riverarebecca@gmail.com       | 1414 David Throughway\\nPort Jason, OH 22070-1220  | SaddleBrown      | 34.305557           | 13.717514   | 36.721283       | 3.120179             | 581.852344          |
# | 4   | mstephens@davidson-herman.com | 14023 Rodriguez Passage\\nPort Jacobville, PR 3... | MediumAquaMarine | 33.330673           | 12.795189   | 37.536653       | 4.446308             | 599.406092          |
#
# In \[5\]:
#
#     # checking the shape of the dataset
#
#     dataset.shape
#
# Out\[5\]:
#
#     (500, 8)
#
# In \[6\]:
#
#     # checking the mathematical elements in the dataset
#     # describe  function is used to give the summary statistics or the mathematical
#     # elements present in the dataset .
#     # if there is very vast difference between the values then we can say it as it might have
#     # the outliers .
#
#     dataset.describe()
#
# Out\[6\]:
#
# |       | Avg. Session Length | Time on App | Time on Website | Length of Membership | Yearly Amount Spent |
# |-------|---------------------|-------------|-----------------|----------------------|---------------------|
# | count | 500.000000          | 500.000000  | 500.000000      | 500.000000           | 500.000000          |
# | mean  | 33.053194           | 12.052488   | 37.060445       | 3.533462             | 499.314038          |
# | std   | 0.992563            | 0.994216    | 1.010489        | 0.999278             | 79.314782           |
# | min   | 29.532429           | 8.508152    | 33.913847       | 0.269901             | 256.670582          |
# | 25%   | 32.341822           | 11.388153   | 36.349257       | 2.930450             | 445.038277          |
# | 50%   | 33.082008           | 11.983231   | 37.069367       | 3.533975             | 498.887875          |
# | 75%   | 33.711985           | 12.753850   | 37.716432       | 4.126502             | 549.313828          |
# | max   | 36.139662           | 15.126994   | 40.005182       | 6.922689             | 765.518462          |
#
# In \[7\]:
#
#     # checking the information present in the dataset
#
#     dataset.info()
#
#     # it has pandas dataframe
#     # it has the 500 rows
#     # here we have all the variables present in the dataset
#     # the data types is also given in front of the column names
#     # if we have the string  values then only we will have the object otherwise
#     # we will get someother data types like float
#     # non - null count ; this means in 500 rows we dont have the null values .
#     # this gives the idea if we have the missing data or not .
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 500 entries, 0 to 499
#     Data columns (total 8 columns):
#      #   Column                Non-Null Count  Dtype
#     ---  ------                --------------  -----
#      0   Email                 500 non-null    object
#      1   Address               500 non-null    object
#      2   Avatar                500 non-null    object
#      3   Avg. Session Length   500 non-null    float64
#      4   Time on App           500 non-null    float64
#      5   Time on Website       500 non-null    float64
#      6   Length of Membership  500 non-null    float64
#      7   Yearly Amount Spent   500 non-null    float64
#     dtypes: float64(5), object(3)
#     memory usage: 31.4+ KB
#
# In \[8\]:
#
#     # exploring bivariate relationships
#     # when we want to plot the bivariate relationships we always go for a scatter plot
#     # or we can use the other plots like line plot or the join plot
#     # when we use the line plot / scatter plot / join plot this is always used for the 2d data
#     # or the 2d axis
#     # if the number of the dimenssions are increasing we use the seaborn library instead of the
#     # matplotlib library
#     # in seaborn we can include number of the statistical graphs which is not possible in matplotlib
#     # so here we are using the seaborn library  for creating the join plot
#     # here we are giving the name of the variable that is to be display on the x axis and y axis
#     # then we have given the name of the data that is dataset . this is the variable that
#     # we have already created
#     # in this kind of plots with the help of vertical bar we can read the results
#
#     sns.jointplot(x='Time on Website',y='Yearly Amount Spent',data=dataset)
#
#     # observations :
#     #  here from the graph we can say as most time spent on the website is 37 mins
#     # if we ar econsidering the minutes
#     # from the yearly amount spent we can say it as 500 is the maximum amount that has been spent by
#     # the customers
#     # X - time on website - independent variable
#     # y - yearly amount spend - dependent variable
#     # here we can say that there is no strong relationship between the variables as
#     # we cannot see any trend / pattern of the dots  so we can say it as this is the scatter plot .
#
# Out\[8\]:
#
#     <seaborn.axisgrid.JointGrid at 0x25d99d87100>
#
# ![](data:image/png;base64,...%0A)
#
# In \[9\]:
#
#     # here we have used the seaborn library for plotting the join plot
#     # we have the elements that is to plotted on the x axis and the y axis
#     # then we have given the name of the data that is dataset
#
#     sns.jointplot(x='Time on App',y='Yearly Amount Spent',data= dataset)
#
#     # observations ;
#     # here we can see that the maximum people is browsing the website 11 - 12 minutes
#     # if we are considering the minutes
#     # here as we can say that this is having the linear relationship  with the positive trend of
#     # the dots as there is the slight trend of the linear relationship
#     # this means more time we spent on the application there is an chance we spent for the purchasing
#     # the subscription and pay the yearly amount
#     #  X - independent variable - time on app
#     # Y - dependent variable - yearly amount spent
#
# Out\[9\]:
#
#     <seaborn.axisgrid.JointGrid at 0x25d99ac2520>
#
# ![](data:image/png;base64,...%0A)
#
# In \[10\]:
#
#     # here we have used the seaborn library for plotting the join plot
#     # we have the elements that is to plotted on the x axis and the y axis
#     # then we have given the name of the data that is dataset
#
#     sns.jointplot(x='Avg. Session Length',y='Yearly Amount Spent',data= dataset)
#
#     # observations ;
#     # here as we can say that the average session length is about 34 minutes
#     # if we are considering the minutes
#     # the yearly amount spent is around 500
#     # it is having the slight positive trend that cannot be ignored
#     #  X - independent variable - average session length
#     # Y - dependent variable - yearly amount spent
#
# Out\[10\]:
#
#     <seaborn.axisgrid.JointGrid at 0x25d94254610>
#
# ![](data:image/png;base64,...%0A)
#
# In \[11\]:
#
#     # here we have used the seaborn library for plotting the join plot
#     # we have the elements that is to plotted on the x axis and the y axis
#     # then we have given the name of the data that is dataset
#
#     sns.jointplot(x='Length of Membership',y='Yearly Amount Spent',data= dataset)
#
#     # observations ;
#     # here as we can say that the the maximum length of membreship is 5 months if we are
#     # considering the months
#     # and the yearly amount spent is 500
#     # it is having the clear positive trend
#     #  X - independent variable - length of membership
#     # Y - dependent variable - yearly amount spent
#     # here the length of the memebreship plays a vital role on determining the amount the customers
#     # anually on the ecommerce websites
#     # scatter plot is the basic plot
#     # if we are desinging the more number of diemenssions we use the join plot
#     # when we are exploring our data we should do more number of visualizations
#
# Out\[11\]:
#
#     <seaborn.axisgrid.JointGrid at 0x25d9aeb4910>
#
# ![](data:image/png;base64,...%0A)
#
# ## Length of Membership has the maximum impact on the dependent variable<a href="#Length-of-Membership-has-the-maximum-impact-on-the-dependent-variable" class="anchor-link">¶</a>
#
# In \[ \]:
#
#     # what are the checks you need to perform byfeault while building the model
#
#     # outlier check
#     # data type check
#     # encoding check - if all the elements have the numerical data type because ML does not understnd the
#     # text  it only understands the numerical values once this are checked then only we can procedd for
#     # the model building
#
# In \[12\]:
#
#     # Training and Testing data
#     # splitting the data into the training set and the testing set
#     # X - independent variable
#     # Y - dependent variable
#     # here we are selecteing the variables from the variable created called dataset
#     # here have selecting all the independent variables from the main dataset and storing it in the
#     # object like X
#     # here we are creating the subset of the main dataset for the 4 variables
#     # so 1st we have created the list and then created the subset so 2nd double bracket is used
#     # for creating the subset we have used the box bracket
#
#     X = dataset[['Avg. Session Length','Time on App','Time on Website','Length of Membership']]
#     y = dataset['Yearly Amount Spent']
#
#     # here we have created the 2 subsets
#     # 1st is the object X and second is the object Y
#
# In \[13\]:
#
#     # here we are importing the train test split module from the sklearn model selection pacakge
#     # here is the 4 subsets that is ; X_train,X_test,y_train,y_test
#     # always give the same order that is X_train,X_test,y_train,y_test
#     # here we have used the train test split to split the original dataset
#     # into X_train,X_test,y_train,y_test order for the variable X and Y that is independent
#     # and the dependent variables
#     # 75 percent will train the algorithm and 25 percent will test the algorithm
#     # why we have given the X , Y
#     # here we have given the X and y beacuse  we are giving the elements to splitted
#     # for X train and X test and similarly we have given the elemnt for y for splitting
#     # the y element into Y train and Y test
#     # OR if we will give the dataset in place of x,y then train test split will be applied
#     # and it will slpit by its own manner
#     # here we have  given the test size of 0.25 that means data will be splitted into 75/ 25 split
#     # random state is used to get the permanent output . if everytime we will run the code the
#     # result will not change . the train and test will be same
#     # we can give any value for the random state
#     # test size / random state depends on our choice
#
#     from sklearn.model_selection import train_test_split
#     X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)
#
# In \[14\]:
#
#     # Training the Classifier
#     # here we are importing the linear regression model from the sklearn.linear_model pacakege
#     # the classifier we are using the linear regression model
#     # what are the linear models
#     # logistic regression model , simple linear regression model and the multiple regression
#     # model are the linear models. all these are the objects of the linear regression class
#     # LinearRegression - this is the class, and this is the object  sklearn.linear_model
#     # the next step will be we will create the class from the object
#
#     from sklearn.linear_model import LinearRegression
#
# In \[15\]:
#
#     # create an object/instance from the class LinearRegression'
#     # here we have created the object lm
#     # lm is the object that represents the linear regression class
#
#     lm= LinearRegression()
#
# In \[16\]:
#
#     # Fitting our training data to train our classifier
#     # here we will fit the X train , Y train data that is the training data into
#     # the object created called lm to build the regression model
#
#     lm.fit(X_train,y_train)
#
# Out\[16\]:
#
#     LinearRegression()
#
# In \[17\]:
#
#     # here we are checking the coeffeicients of the variable careted called lm
#
#     lm.coef_
#
# Out\[17\]:
#
#     array([25.69083176, 38.68815596,  0.45279908, 61.71050259])
#
# In \[18\]:
#
#     # Predicting the test data
#     # here we have created the variable called predictions
#     # then we are predicting the x  test values from the previously created variable called lm
#
#     predictions = lm.predict(X_test)
#
# In \[19\]:
#
#     # create a scatterplot to test the actuals with the predictions
#     #  scatter plot is the 2d plot
#     # here we have selected the y test for the actual values
#     # then we have given the x label that is x axis and y label that is y axis
#
#     plt.scatter(y_test,predictions)
#     plt.xlabel('y_test')
#     plt.ylabel('predictions')
#
#     # obeservations
#     # it is positively correlated or it is a straight line
#
# Out\[19\]:
#
#     Text(0, 0.5, 'predictions')
#
# ![](data:image/png;base64,...%0A)
#
# In \[20\]:
#
#     # here we are importing the metrics module from the sklearn pacakge
#
#     from sklearn import metrics
#
# In \[21\]:
#
#     # whatever we are displaying in red that means we are labeling our output
#     # here we are printing the mean squared error
#     # then we will write the metrics for calculating the mean squared error
#     # the two objects are important for calculating the MSE that is y test set and predictions
#     # y test set and predictions  - this 2 objects are neccessary for calculating the MSE
#     # what is MSE - it is the difference between the actuals and the predictions .
#     # the diffrence between the actuals and the predictions is the error componenet
#
#     print('MSE :-'," ",metrics.mean_squared_error(y_test,predictions))
#
#     MSE :-   105.64514296279496
#
# #### Calculating the R2 value to measure the accuracy--<a href="#Calculating-the-R2-value-to-measure-the-accuracy--" class="anchor-link">¶</a>
#
# In \[22\]:
#
#     # here we are importing the r2 score module from skelarn  metrics
#     # here we have created the varaibale called r2 for calculating it
#     # then we are calculating the r2 score for the objects called _test and predictions
#     # then we will print the r2
#     # MSE will never give the accurate values so we never go with the r square .
#
#     from sklearn.metrics import r2_score
#     r2 = r2_score(y_test,predictions)
#     print(r2)
#
#     # observation ;
#     # 98 percent is accuracy that means the model is good
#
#     0.9806693454258992
#
# #### 1. Ridge Regression:<a href="#1.-Ridge-Regression:" class="anchor-link">¶</a>
#
# In \[23\]:
#
#     # firstly we have imported the sklearn pacakge
#     # here we are Importing Ridge module from the linear model under the sklearn pacakge
#     # then we have the created the variable called  ridgeReg
#     # alpha=0.001 - this is the bydefault value of 1
#     # we can increase the alpha upto 1 but we generally do not increase the value of alpha
#     # alpha is the regularization parameter
#     # By setting normalize=True, the object returned will contain the relative frequencies of the
#     # unique values.
#     # The normalize parameter is set to False by default
#     # then we are setting the X_train,y_train set in the previaously created variabled called ridgeReg
#
#     import sklearn
#     from sklearn.linear_model import Ridge
#     ridgeReg = Ridge(alpha=0.001, normalize=True)
#     ridgeReg.fit(X_train,y_train)
#
#     C:\Users\Ankita\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
#     If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
#     from sklearn.pipeline import make_pipeline
#
#     model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
#     If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
#     kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
#     model.fit(X, y, **kwargs)
#
#     Set parameter alpha to: original_alpha * n_samples.
#       warnings.warn(
#
# Out\[23\]:
#
#     Ridge(alpha=0.001, normalize=True)
#
# In \[ \]:
#
#     # what is the residual sum of squares
#     # the predictioner that is y hat - y1 , RSS AND ESS we know there will be the variation in
#     # the actual and the predictor
#     # now these total variation in the actual value of y  and the predicted values of y will be
#     # dividing it by or breaking it into the 2 components
#     # that is 1 variation that is due to the model and the another variation that is not due to the model
#     # this is the inherent variation
#     # it can be reduced the noise element or any unexplained factor
#     # so theis is the residual sum of squares that means what is the left time
#     # explained sum of squares means which variation occurs due to the model that is y hat - Yn
#     # every x has an coeffcients that is having the beta values which is the x values or the x values is
#     # the slope coeffcients
#     # if x3 becomes 0 the entire x3 component will become o - hypothesis situation
#     # we are not increasing the alpha value as there is no need to increase
#     # what are the standard checks we do while deploying the model
#     # 1 - overfitting problem [ generally occurs ]
#     # there is the solution of cross validation which helps to resolve the overfitting problem
#     # when the model is running on the very low accuracy  then we will do the cross validation check
#     # test set and training set - both will give the accuracy
#     # if the training set accuracy is very high  and the test set accuracy is very low  then there is
#     # no oberfitting in the model
#     # test dat awill give the actual accuracy, training set  does not give
#     # accuraccy of the test set is very important because it is the new data and model learns from
#     # the training data
#     # in r square the alpha is replaced and explained with the lambda
#     # alpha is the penalty term which is used to scale down the coeffcients values
#
# #### Evaluating using RMSE:<a href="#Evaluating-using-RMSE:" class="anchor-link">¶</a>
#
# In \[24\]:
#
#     # after performing the ridge regression we are checking  the accuracy
#     # here we are checking when we fit the normal regression what was the accuracy and when you include
#     # the alpha what was the accuracy
#     # by inclusion of alpha if the accuracy is increased then the model is  good
#     # or if the accuracy of the model is not good then again we will increase the value of the alpha
#     # and again we will re- run the value and check the r square
#     # changing the value of alpha again and again to increase the accuracy of the model is called as
#     # the hyperparameter tuned
#     # alpha is also the hyperparameter term
#     # change the value of alpha and run it till the value of the r square is statisfied
#     # R2 Value/Coefficient of Determination: {} - this means i want to print the test value
#     # so when you will print then you will get the r square value of coeficient
#
#     print(np.sqrt(sklearn.metrics.mean_squared_error(y_train, ridgeReg.predict(X_train))))
#     print(np.sqrt(sklearn.metrics.mean_squared_error(y_test, ridgeReg.predict(X_test))))
#     print('R2 Value/Coefficient of Determination: {}'.format(ridgeReg.score(X_test, y_test)))
#
#     9.808344681882627
#     10.276384031005357
#     R2 Value/Coefficient of Determination: 0.980676861070679
#
# #### 2. Lasso Regression:<a href="#2.-Lasso-Regression:" class="anchor-link">¶</a>
#
# ## The alpha value determines how much weight is given to the penalty term. A higher alpha value means that more weight is given to the penalty term, and a lower alpha value means that less weight is given to the penalty term.<a href="#The-alpha-value-determines-how-much-weight-is-given-to-the-penalty-term.-A-higher-alpha-value-means-that-more-weight-is-given-to-the-penalty-term,-and-a-lower-alpha-value-means-that-less-weight-is-given-to-the-penalty-term." class="anchor-link">¶</a>
#
# ### It is necessary to standardize variables before using Lasso and Ridge Regression. Lasso regression puts constraints on the size of the coefficients associated to each variable. However, this value will depend on the magnitude of each variable.<a href="#It-is-necessary-to-standardize-variables-before-using-Lasso-and-Ridge-Regression.-Lasso-regression-puts-constraints-on-the-size-of-the-coefficients-associated-to-each-variable.-However,-this-value-will-depend-on-the-magnitude-of-each-variable." class="anchor-link">¶</a>
#
# In \[ \]:
#
#     # what is laso and ridge
#     # it is the automated process by which the least important elements are dropped from the process
#     # in some cases we can judge by our intution so in that case there is no need to perform the laso
#     # and ridge
#
# In \[25\]:
#
#     # Importing Lasso
#     #  here we are Importing lasso module from the linear model under the sklearn pacakge
#     # then we have the created the variable called  lassoreg
#     # alpha=0.001 - this is the bydefault value of 1
#     # we can increase the alpha upto 1 but we generally do not increase the value of alpha
#     # alpha is the regularization parameter
#     # By setting normalize=True, the object returned will contain the relative frequencies of the
#     # unique values.
#     # The normalize parameter is set to False by default
#     # then we are setting the X_train,y_train set in the previaously created variabled called ridgeReg
#
#     here we have the value of alpha 0.001
#     from sklearn.linear_model import Lasso
#     lassoreg = Lasso(alpha=0.001, normalize=True)  # alpha is the penalty term
#     lassoreg.fit(X_train,y_train)
#
#     C:\Users\Ankita\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
#     If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
#     from sklearn.pipeline import make_pipeline
#
#     model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
#     If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
#     kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
#     model.fit(X, y, **kwargs)
#
#     Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#       warnings.warn(
#
# Out\[25\]:
#
#     Lasso(alpha=0.001, normalize=True)
#
# #### Evaluating using RMSE:<a href="#Evaluating-using-RMSE:" class="anchor-link">¶</a>
#
# In \[26\]:
#
#     # here we are checking when we fit the normal regression what was the accuracy and when
#     # you include the alpha what was the accuracy
#     # by inclusion of alpha if the accuracy is increased then the model is  good
#     # or if the accuracy of the model is not good then again we will increase the value of the alpha
#     # and again we will re- run the value and check the r square
#     # changing the value of alpha again and again to increase the accuracy of the model is called
#     # as the hyperparameter tuned
#     # alpha is also the hyperparameter term
#     # change the value of alpha and run it till the value of the r square is statisfied
#     # R2 Value/Coefficient of Determination: {} - this means i want to print the test value
#     # so when you will print then you will get the r square value of coeficient
#
#     print(np.sqrt(sklearn.metrics.mean_squared_error(y_train, lassoreg.predict(X_train))))
#     print(np.sqrt(sklearn.metrics.mean_squared_error(y_test, lassoreg.predict(X_test))))
#     print('R2 Value/Coefficient of Determination: {}'.format(lassoreg.score(X_test, y_test)))
#
#     9.808124960704793
#     10.277729139358998
#     R2 Value/Coefficient of Determination: 0.9806718022062803
#
# #### 3. ElasticNet Regression:<a href="#3.-ElasticNet-Regression:" class="anchor-link">¶</a>
#
# In \[27\]:
#
#     # Importing ElasticNet
#     #  here we are Importing elastic net  module from the linear model under the sklearn pacakge
#     # then we have the created the variable called  elastic
#     # alpha=0.001 - this is the bydefault value of 1
#     # we can increase the alpha upto 1 but we generally do not increase the value of alpha
#     # alpha is the regularization parameter
#     # By setting normalize=True, the object returned will contain the relative frequencies of the unique
#     # values.
#     # The normalize parameter is set to False by default
#     # then we are setting the X_train,y_train set in the previaously created variabled called elastic
#
#     from sklearn.linear_model import ElasticNet
#     Elastic = ElasticNet(alpha=0.001, normalize=True)
#     Elastic.fit(X_train,y_train)
#
#     C:\Users\Ankita\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
#     If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
#     from sklearn.pipeline import make_pipeline
#
#     model = make_pipeline(StandardScaler(with_mean=False), ElasticNet())
#
#     If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
#     kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
#     model.fit(X, y, **kwargs)
#
#     Set parameter alpha to original_alpha * np.sqrt(n_samples) if l1_ratio is 1, and to original_alpha * n_samples if l1_ratio is 0. For other values of l1_ratio, no analytic formula is available.
#       warnings.warn(
#
# Out\[27\]:
#
#     ElasticNet(alpha=0.001, normalize=True)
#
# #### Evaluating using RMSE:<a href="#Evaluating-using-RMSE:" class="anchor-link">¶</a>
#
# In \[28\]:
#
#     # here we are checking when we fit the normal regression what was the accuracy and when you
#     # include the alpha what was the accuracy
#     # by inclusion of alpha if the accuracy is increased then the model is  good
#     # or if the accuracy of the model is not good then again we will increase the value of the alpha
#     # and again we will re- run the value and check the r square
#     # changing the value of alpha again and again to increase the accuracy of the model is called as the
#     # hyperparameter tuned
#     # alpha is also the hyperparameter term
#     # change the value of alpha and run it till the value of the r square is statisfied
#     # R2 Value/Coefficient of Determination: {} - this means i want to print the test value
#     # so when you will print then you will get the r square value of coeficient
#
#     print(np.sqrt(sklearn.metrics.mean_squared_error(y_train, Elastic.predict(X_train))))
#     print(np.sqrt(sklearn.metrics.mean_squared_error(y_test, Elastic.predict(X_test))))
#     print('R2 Value/Coefficient of Determination: {}'.format(Elastic.score(X_test, y_test)))
#
#     15.556892349777891
#     14.92127304211538
#     R2 Value/Coefficient of Determination: 0.9592611485986489
#
# ### If Alpha is close to zero, the Ridge term itself is very small and thus the final error is based on RSS alone. If Alpha is too large, the impact of shrinkage grows and the coefficients B1, B2 ... Bn tends to zero.<a href="#If-Alpha-is-close-to-zero,-the-Ridge-term-itself-is-very-small-and-thus-the-final-error-is-based-on-RSS-alone.-If-Alpha-is-too-large,-the-impact-of-shrinkage-grows-and-the-coefficients-B1,-B2-...-Bn-tends-to-zero." class="anchor-link">¶</a>
#
# In \[ \]:
#
#     # how many total accuracy we get
#     # after getting the accuracy from the normal regression , ridge regression , laso regression ,
#     # elastics net
#     # so total we are having the 4 accuracy
#     # whoseever accuracy is higher we will take that model like it may be normal , ridge , laos or
#     # the elastic net regression models
#     # these are the  additional steps [ hypothetical situation]
#     # it may happen that the normal ridge regression will give the normal accuracy
#     # in real time data/ production life if the accuracy of the model is greater than 60 perecnt then
#     # the model is good or if the accuracy is less than 60 perecnt then the model is not good we need
#     # to increase the accuracy of the model
#     # if we are doing the normal regression we can also do the laso and ridge regression along with it
#     # to increase the more accuracy
#     # if the accuracy is 98 perecnt we dont even apply the laso and ridge because we are having the good
#     # accuracy in hand
#     # what is the classification problem
#     # we usually focus on the dicotomous respone
#     # what is dicotomous respone
#     # yes , no , male , female , died , live
#     # dicotomous respone means dual response
#     # classification is suitable for that type of refferences where we have only dual or only two
#     # responses. when we have such data set we fit the classification model
#     # basic model for the classification is the logistic regression model
#     # logistic regression
#     # it is the linear model
#     # when it is the linear model it should overcome all the points of the clasical linear regression
#     # model[CLRM]
#     # what is the assumption of the CLRM
#     # x and y will be linearly related means x and y should have the linear relationship means if you
#     # plot the value of x with  respect to y then we will get the staright line
#     # for ex. price demand plot like if the demand increases price will also increases or if the price
#     # decreases the demand will also decreases
#     # it is having the direct relationship then it will be linearly related
#     # if x incrases y increases or if the x decreases  then y also decreases
#     # in the normal regression model y was quantative
#     # there are 2 types of variables - quananative and qualtative
#     # quantataive means something that can be measured in numbers / given in the form of numbers
#     # like sales ...
#     # qualatative - it means that something which cannot be measured in numbers . it is having
#     # the response like yes / no ...
#
# In \[ \]:
#
#
#
# In \[ \]:
